# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import datasets

# %%
accidents= pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")

# %%
accidents.tail()
# Out:
#                     Id District Name Neighborhood Name  \
# 10334  2017S003667       Sant Andreu     el Bon Pastor
# 10335  2017S001896       Sant Andreu     el Bon Pastor
# 10336  2017S010718       Sant Andreu     el Bon Pastor
# 10337  2017S006145       Sant Andreu     el Bon Pastor
# 10338  2017S000178       Sant Andreu     el Bon Pastor
#
#                                                   Street    Weekday     Month  \
# 10334  Litoral (Llobregat)                           ...    Tuesday     April
# 10335  PL MONTERREY                                  ...  Wednesday     March
# 10336  Litoral (Llobregat)                           ...   Thursday  December
# 10337  Litoral (Besòs)                               ...     Friday      July
# 10338  CIUTAT D'ASUNCIÓN                             ...     Sunday   January
#
#        Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 10334   25     8         Morning              1                 0        1
# ...

# %%
motorcycles= pd.read_csv("datasets/1.-Transportation/2017_cilindrada_motos.csv")

# %%
motorcycles.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017               1  Ciutat Vella           1
# 1  2017               1  Ciutat Vella           2
# 2  2017               1  Ciutat Vella           3
# 3  2017               1  Ciutat Vella           4
# 4  2017               2      Eixample           5
#
#                                Nom_Barri Cilindrada_motos  Nombre_motos
# 0                               el Raval     Fins a 75 cc            93
# 1                         el Barri Gòtic     Fins a 75 cc           133
# 2                         la Barceloneta     Fins a 75 cc           200
# 3  Sant Pere, Santa Caterina i la Ribera     Fins a 75 cc           224
# 4                          el Fort Pienc     Fins a 75 cc           177

# %% [markdown]
# # Prepare for merge

# %%
# Change column name, same as accidents (Neighborhood Name)
motor_new= motorcycles.rename(columns={"Nom_Barri":"Neighborhood Name"})

# 592 different neighborhoods
motor_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
# Any                  592 non-null int64
# Codi_Districte       592 non-null int64
# Nom_Districte        592 non-null object
# Codi_Barri           592 non-null int64
# Neighborhood Name    592 non-null object
# Cilindrada_motos     592 non-null object
# Nombre_motos         592 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 32.5+ KB

# %%
# 10339 different neighborhoods
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10339 entries, 0 to 10338
# Data columns (total 15 columns):
# Id                   10339 non-null object
# District Name        10339 non-null object
# Neighborhood Name    10339 non-null object
# Street               10339 non-null object
# Weekday              10339 non-null object
# Month                10339 non-null object
# Day                  10339 non-null int64
# Hour                 10339 non-null int64
# Part of the day      10339 non-null object
# Mild injuries        10339 non-null int64
# Serious injuries     10339 non-null int64
# Victims              10339 non-null int64
# Vehicles involved    10339 non-null int64
# Longitude            10339 non-null float64
# Latitude             10339 non-null float64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.2+ MB

# %%
# accident(Neighborhood Name) 10339->592
accidents_copy= accidents.copy()
# First sum up all accidents per neighborhood
# first mistake: can not drop duplicates because ALL duplicates are dropped
#accidents_new.drop_duplicates(subset = "Neighborhood Name", keep= False, inplace= True)

#new 
df= accidents.groupby(["Neighborhood Name"])["Victims"].count()
df
df2= pd.DataFrame(df)
print(df2)


df3 = motor_new.groupby(["Neighborhood Name"])["Nombre_motos"].count()
df4= pd.DataFrame(df3)
print(df4)
# Shorter accident df
#accidents_new= accidents_copy.stack()


#motor_neigh= pd.pivot_table(data= motor_new, values="Nombre_motos", index="Neighborhood Name", columns="Cilindrada_motos")
#motor_neigh
# Out:
#                                               Victims
# Neighborhood Name
# Baró de Viver                                      31
# Can Baró                                           15
# Can Peguera                                         8
# Canyelles                                          34
# Ciutat Meridiana                                   11
# Diagonal Mar i el Front Marítim del Poblenou      146
# Horta                                             148
# Hostafrancs                                       125
# Montbau                                            51
# Navas                                              64
# Pedralbes                                         204
# Porta                                              98
# Provençals del Poblenou                           181
# Sant Andreu                                       197
# Sant Antoni                                       233
# Sant Genís dels Agudells                           52
# ...

# %% [markdown]
# # Merging

# %%
# 'inner' because we want to create a dataframe evaluating neighborhoods, dont want to evaluate neighborhoods without
# data regarding the amount of motorcycles

#merged = pd.merge(accidents,motor_new, how='inner', on='Neighborhood Name')
#print(accidents.info())
#merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80624 entries, 0 to 80623
# Data columns (total 21 columns):
# Id                   80624 non-null object
# District Name        80624 non-null object
# Neighborhood Name    80624 non-null object
# Street               80624 non-null object
# Weekday              80624 non-null object
# Month                80624 non-null object
# Day                  80624 non-null int64
# Hour                 80624 non-null int64
# Part of the day      80624 non-null object
# Mild injuries        80624 non-null int64
# Serious injuries     80624 non-null int64
# Victims              80624 non-null int64
# Vehicles involved    80624 non-null int64
# Longitude            80624 non-null float64
# Latitude             80624 non-null float64
# Any                  80624 non-null int64
# Codi_Districte       80624 non-null int64
# Nom_Districte        80624 non-null object
# Codi_Barri           80624 non-null int64
# ...

# %% [markdown]
# # Accidents difference

# %%
import pandas as pd

# %%
# Accidents
df_2017 = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")
df_2016 = pd.read_csv("datasets/1.-Transportation/2016_accidents_gu_bcn.csv")
# Motorcycles
motos_2017 = pd.read_csv("../datasets/1.-Transportation/2017_cilindrada_motos.csv")
motos_2016 = pd.read_csv("../datasets/1.-Transportation/2016_cilindrada_motos (1).csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0bb394e9abad> in <module>
#       3 df_2016 = pd.read_csv("datasets/1.-Transportation/2016_accidents_gu_bcn.csv")
#       4 # Motorcycles
# ----> 5 motos_2017 = pd.read_csv("../datasets/1.-Transportation/2017_cilindrada_motos.csv")
#       6 motos_2016 = pd.read_csv("../datasets/1.-Transportation/2016_cilindrada_motos (1).csv")
#
# ...

# %%
motos_2016.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-95251d2d0436> in <module>
# ----> 1 motos_2016.head()
#
# NameError: name 'motos_2016' is not defined
